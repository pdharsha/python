# %% [markdown]
# <a href="https://colab.research.google.com/github/pdharsha/python/blob/master/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Line chart
# plot(x,y)
# i want to analyse the monthly temprature
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp)
plt.show()

# %%
# xlabel , y label , tilte
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
# change line color, marker , marker size
# color 
# marker
# markersize
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='b', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
# compare the line chart for this year and last year
month= ['jan','feb','march','april','may','june']
temp2022= [10,30,45,12,32,5]
temp2021= [40,30,15,22,10,20]
plt.plot(month,temp2022 , color='b', marker='o', markersize=10)
plt.plot(month,temp2021 , color='r', marker='o', markersize=10)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
month= ['jan','feb','march','april','may','june']
temp2022= [10,30,45,12,32,5]
temp2021= [40,30,15,22,10,20]
plt.plot(month,temp2022 , color='b', marker='o', markersize=10 , label='2022')
plt.plot(month,temp2021 , color='r', marker='o', markersize=10 ,  label='2021')
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.legend()
plt.show()

# %%
# extending fig size
plt.figure(figsize=(10,5))
month= ['jan','feb','march','april','may','june']
temp2022= [10,30,45,12,32,5]
temp2021= [40,30,15,22,10,20]
plt.plot(month,temp2022 , color='b', marker='o', markersize=10 , label='2022')
plt.plot(month,temp2021 , color='r', marker='o', markersize=10 ,  label='2021')
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.legend()
plt.show()

# %%
# subplotting
plt.figure(figsize=(10,5))
# 2 R 2 C

# subplot-1
plt.subplot(2,2,1)


# subplot-2
plt.subplot(2,2,2)


# subplot-3
plt.subplot(2,2,3)


# subplot-4
plt.subplot(2,2,4)


plt.show()

# %%
# subplotting
plt.figure(figsize=(10,10))
# 2 R 2 C

# subplot-1
plt.subplot(2,2,1)
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='b', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')

# subplot-2
plt.subplot(2,2,2)
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='r', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')

# subplot-3
plt.subplot(2,2,3)
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='g', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')

# subplot-4
plt.subplot(2,2,4)
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='r', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')

plt.show()

# %%
# save the figure

# subplotting
plt.figure(figsize=(10,10))
# 2 R 2 C

# subplot-1
plt.subplot(2,2,1)
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='b', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')

# subplot-2
plt.subplot(2,2,2)
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='r', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')

# subplot-3
plt.subplot(2,2,3)
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='g', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')

# subplot-4
plt.subplot(2,2,4)
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.plot(month,temp , color='r', marker='o', markersize=15)
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')

# to save figure
plt.savefig('abc.png')

plt.show()

# %% [markdown]
# ## **Scatter Chart**

# %%
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.scatter(month,temp , color='b')
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.scatter(month,temp , color='b', s=100)
plt.plot(month,temp , color='r')
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
# Task : i need to analyse the pattern on D . ND between (age and glucose)

df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
nd = df[df.Outcome==0]
nd.head()
# Out:
#     Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1        85             66             29        0  26.6
# 3        89             66             23       94  28.1
# 5       116             74              0        0  25.6
# 7       115              0              0        0  35.3
# 10      110             92              0        0  37.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 1                      0.351   31        0
# 3                      0.167   21        0
# 5                      0.201   30        0
# 7                      0.134   29        0
# 10                     0.191   30        0

# %%
d = df[df.Outcome==1]
d.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 2      183             64              0        0  23.3
# 4      137             40             35      168  43.1
# 6       78             50             32       88  31.0
# 8      197             70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 2                     0.672   32        1
# 4                     2.288   33        1
# 6                     0.248   26        1
# 8                     0.158   53        1

# %%
plt.figure(figsize=(12,5))

# subplot -1 (ND)
plt.subplot(1,2,1)
plt.scatter(nd.Age , nd.Glucose ,color='b' ,s=5 )
plt.xlabel('age')
plt.ylabel('Glucose')
plt.title('Non-diabetic')

# subplot -2 (D)
plt.subplot(1,2,2)
plt.scatter(d.Age , d.Glucose ,color='r',s=5 )
plt.xlabel('age')
plt.ylabel('Glucose')
plt.title('diabetic')

plt.show()

# %%
# barchart
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.bar(month,temp )
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
plt.figure(figsize=(10,5))
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.bar(month,temp )
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
plt.figure(figsize=(10,5))
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.bar(month,temp , color='g' )
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
plt.figure(figsize=(10,5))
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.bar(month,temp , color=['g','r'] )
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
plt.figure(figsize=(10,5))
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.bar(month,temp , color=['g','r'] ,width= 0.5 )
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
plt.figure(figsize=(10,5))
month= ['jan','feb','march','april','may','june']
temp= [10,30,45,12,32,5]
plt.barh(month,temp , color=['g','r'])
plt.xlabel('Months')
plt.ylabel('Temprature')
plt.title('analyse the monthly temprature')
plt.show()

# %%
# Seaborn
nba = pd.read_csv('nba.csv')

# %%
# univariate : those chart which use only single column - histogram , kde , box plot
# bivariate : those chart which use 2 columns

# %%
# Histogram 
# syntax : sns.distplot(df.col , hist= False || kde= False)
sns.distplot(df.Glucose)

# %%
sns.distplot(df.Glucose , kde= False)

# %%
plt.figure(figsize=(10,7))
sns.distplot(df.Glucose , kde= False,bins=5)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.distplot(df.Glucose , hist= False,bins=5)
plt.show()

# %%
# task : i need all columns using subplot
col = df.columns
plt.figure(figsize=(12,12))
for i in range(len(col)):
  plt.subplot(3,3,i+1)
  sns.distplot(df[col[i]], kde = False)
plt.show()

# %%
# task : i need all columns using subplot
col = df.columns
plt.figure(figsize=(12,12))
for i in range(len(col)):
  plt.subplot(3,3,i+1)
  sns.distplot(df[col[i]], hist = False)
plt.show()

# %%
# Pair plot (n*n)'
#syntax = sns.pairplot(df)
sns.pairplot(df)

# %%
sns.pairplot(df , hue ='Outcome')

# %%
# Joint plot : kind = scatter , kde ,hex , reg 

sns.jointplot(x ='Age', y= 'Glucose', data=df , kind ='scatter')

# %%
sns.jointplot(x ='Age', y= 'Glucose', data=df , kind ='hex')

# %%
# Regression : 
sns.regplot(x ='Age', y= 'Glucose', data=df)

# %%
sns.regplot(x ='Age', y= 'BloodPressure', data=df)

# %%
# corealtion
cor_mat = df.corr()

# %%
cor_mat
# Out:
#                            Glucose  BloodPressure  SkinThickness   Insulin  \
# Glucose                   1.000000       0.152590       0.057328  0.331357
# BloodPressure             0.152590       1.000000       0.207371  0.088933
# SkinThickness             0.057328       0.207371       1.000000  0.436783
# Insulin                   0.331357       0.088933       0.436783  1.000000
# BMI                       0.221071       0.281805       0.392573  0.197859
# DiabetesPedigreeFunction  0.137337       0.041265       0.183928  0.185071
# Age                       0.263514       0.239528      -0.113970 -0.042163
# Outcome                   0.466581       0.065068       0.074752  0.130548
#
#                                BMI  DiabetesPedigreeFunction       Age  \
# Glucose                   0.221071                  0.137337  0.263514
# BloodPressure             0.281805                  0.041265  0.239528
# SkinThickness             0.392573                  0.183928 -0.113970
# ...

# %%
# heat map
plt.figure(figsize=(12,8))
sns.heatmap(cor_mat, annot=True)

# %%
new_f = ['Glucose','BMI','Age','Outcome']

# %%
new_df = df[new_f]

# %%
new_df
# Out:
#      Glucose   BMI  Age  Outcome
# 0        148  33.6   50        1
# 1         85  26.6   31        0
# 2        183  23.3   32        1
# 3         89  28.1   21        0
# 4        137  43.1   33        1
# ..       ...   ...  ...      ...
# 763      101  32.9   63        0
# 764      122  36.8   27        0
# 765      121  26.2   30        0
# 766      126  30.1   47        1
# 767       93  30.4   23        0
#
# [768 rows x 4 columns]

# %%
# Count Plot 
df.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
sns.countplot(x='Outcome',data= df)

# %%
sns.countplot(y='Outcome',data= df)

# %%
# Box plot 

df.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   120.894531      69.105469      20.536458   79.799479   31.992578
# std     31.972618      19.355807      15.952218  115.244002    7.884160
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     99.000000      62.000000       0.000000    0.000000   27.300000
# 50%    117.000000      72.000000      23.000000   30.500000   32.000000
# 75%    140.250000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.240885    0.348958
# std                    0.331329   11.760232    0.476951
# min                    0.078000   21.000000    0.000000
# ...

# %%
sns.boxplot(y='Glucose', data=df)

# %%
sns.boxplot(x = 'Outcome',y='Glucose', data=df)

# %%
col
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
col = df.columns
plt.figure(figsize=(15,15))
for i in range(len(col)-1):
  plt.subplot(3,3,i+1)
  sns.boxplot(x = 'Outcome',y=col[i], data=df)
plt.show()

# %%
# lmplot 
sns.lmplot(x ='Age', y= 'Glucose', data =df)

# %%
sns.lmplot(x ='Age', y= 'Glucose', data =df , hue ='Outcome')

# %%
# Label Encoding

fruits = ['Orange','Apple','Banana','Cerry']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
new_fruits= le.fit_transform(fruits)

# %%
new_fruits
# Out:
# array([3, 0, 1, 2])

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age     DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.Position.value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba.Position = le.fit_transform(nba.Position)

# %%
nba.head()
# Out:
#             Name            Team  Number  Position  Age     DOB  Weight  \
# 0  Avery Bradley  Boston Celtics       0         2   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99         3   25   6-Jun     235
# 2   John Holland  Boston Celtics      30         4   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28         4   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8         1   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.Position.value_counts()
# Out:
# 4    102
# 1    100
# 2     92
# 3     85
# 0     78
# Name: Position, dtype: int64
